# %% [markdown]
# # act_report

# %% [markdown]
# ## Analyzing and Visualizing

# %% [markdown]
# WeRateDogs is a Twitter account that rates people's dogs with humorous comments about the dog.
#
#
# #### The most popular dog breed
#
# WeRateDogs has over 6000+ tweets. I was able to analyzed around 1500+
# tweets. The most rated dog was golden retriever with more than 140 ratings.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Most common dogs style
#
# The most common dog's style is pupper

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Most common Dog name
#
# The most common name is Charlie, after which come Cooper, Lucy and Oliver

# %% [markdown]
# ![image.png](attachment:image.png)
